# %% [markdown]
# # GLOBAL TERRORISM EXPLORARTORY DATA ANALYSIS

# %% [markdown]
# In this project we were provided with a datset and we had to perform deep exploratory data analysis to find which country has faced most attacks and which country has faced severe loss using different graphs and visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the Dataset

# %%
df=pd.read_csv("globalterrorist.csv",encoding =('ISO-8859-1'),low_memory =False)
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# # Basic info about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# We analyzed that the dataset provided to us has a total over 135 columns of type float64(55),int64(22)and object(58) therefore we need to apply a loop to access them and display them

# %%
df.describe(include="all")
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %%
for i in df.columns:
    print(i,end='\n')
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %% [markdown]
# All the columns in the dataset.

# %%
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]

# %% [markdown]
# On going through the data we analyzed that for the EDA we need to perform we need only certain columns to get a clear picture of our dataset.Doing so we save time and make the process easier.

# %%
df
# Out:
#         iyear  imonth  iday         country_txt                   region_txt  \
# 0        1970       7     2  Dominican Republic  Central America & Caribbean
# 1        1970       0     0              Mexico                North America
# 2        1970       1     0         Philippines               Southeast Asia
# 3        1970       1     0              Greece               Western Europe
# 4        1970       1     0               Japan                    East Asia
# ...       ...     ...   ...                 ...                          ...
# 181686   2017      12    31             Somalia           Sub-Saharan Africa
# 181687   2017      12    31               Syria   Middle East & North Africa
# 181688   2017      12    31         Philippines               Southeast Asia
# 181689   2017      12    31               India                   South Asia
# 181690   2017      12    31         Philippines               Southeast Asia
#
# ...

# %% [markdown]
# # Dropping all NULL values

# %%
df.dropna(axis=0,inplace=True)
# Out:
# C:\Users\Radhika Bajaj\AppData\Local\Temp\ipykernel_17088\2311172004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# iyear              0
# imonth             0
# iday               0
# country_txt        0
# region_txt         0
# provstate          0
# city               0
# latitude           0
# longitude          0
# location           0
# summary            0
# attacktype1_txt    0
# targtype1_txt      0
# gname              0
# motive             0
# weaptype1_txt      0
# nkill              0
# nwound             0
# addnotes           0
# dtype: int64

# %% [markdown]
# We get all data values to be NULL free

# %%
df.head()
# Out:
#     iyear  imonth  iday    country_txt     region_txt    provstate  \
# 14   1970       1     9  United States  North America  Puerto Rico
# 17   1970       1    12  United States  North America     New York
# 22   1970       1    19  United States  North America   Washington
# 24   1970       1    19  United States  North America   New Jersey
# 30   1970       1    25  United States  North America     New York
#
#              city   latitude   longitude                 location  \
# 14    Rio Piedras  18.386932  -66.061127  Caparra Shopping Center
# 17  New York City  40.697132  -73.931351                 Brooklyn
# 22        Seattle  47.610786 -122.331306       Seattle University
# 24    Jersey City  40.717892  -74.067467        Front of building
# 30  New York City  40.697132  -73.931351                Manhattan
#
#                                               summary  \
# 14  1/9/1970:  The Armed Commandos of Liberation c...
# ...

# %%
df.tail()
# Out:
#         iyear  imonth  iday  country_txt          region_txt  \
# 181464   2017      12    22      Nigeria  Sub-Saharan Africa
# 181588   2017      12    28  Afghanistan          South Asia
# 181602   2017      12    28  Philippines      Southeast Asia
# 181641   2017      12    24      Nigeria  Sub-Saharan Africa
# 181672   2017      12    31        India          South Asia
#
#                 provstate           city   latitude   longitude  \
# 181464             Kaduna         Nindem   9.428792    8.333605
# 181588              Kabul          Kabul  34.516895   69.147011
# 181602        Maguindanao  Shariff Aguak   6.862806  124.443649
# 181641              Benue         Odonto   7.042064    8.003725
# 181672  Jammu and Kashmir      Lethapora  33.966527   74.964225
#
#                                                location  \
# 181464         The incident occurred in Jemaa district.
# 181588  The incident occurred in the Pule Sokhtia area.
# ...

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# HEATMAP

# %%
df.corr()
# Out:
# C:\Users\Radhika Bajaj\AppData\Local\Temp\ipykernel_17088\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               iyear    imonth      iday  latitude  longitude     nkill  \
# iyear      1.000000  0.039815  0.017615 -0.221458   0.566008  0.114273
# imonth     0.039815  1.000000  0.002231 -0.022655   0.053266 -0.017874
# iday       0.017615  0.002231  1.000000 -0.009111  -0.006585 -0.003907
# latitude  -0.221458 -0.022655 -0.009111  1.000000  -0.069478  0.025588
# longitude  0.566008  0.053266 -0.006585 -0.069478   1.000000  0.105855
# nkill      0.114273 -0.017874 -0.003907  0.025588   0.105855  1.000000
# nwound     0.100210 -0.005454  0.006843  0.050880   0.095147  0.604791
#
#              nwound
# iyear      0.100210
# imonth    -0.005454
# iday       0.006843
# ...

# %%
sns.heatmap(df.corr())
plt.show()
# Out:
# C:\Users\Radhika Bajaj\AppData\Local\Temp\ipykernel_17088\2975651719.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(df.head(100))

# %% [markdown]
#  BOXPLOT
#
#
# :For number of crimes every year

# %%
df[['iyear']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Bar graph for representing crimes every year

# %%
attacks=df["iyear"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","iyear":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      126
# 1971       58
# 1972       36
# 1973       18
# 1974       23

# %%
attacks.plot(kind="bar",color="#6fc19e",figsize=(15,6),fontsize=10)
plt.title("Terror Attacks",fontsize=10)
plt.xlabel("TIMELINE",fontsize=10)
plt.ylabel("Attacks",fontsize=10)
plt.show()

# %% [markdown]
# This tell us that most crimes were commited in 2014 and the least in 1971

# %%
reg=pd.crosstab(df.iyear,df.country_txt)
reg.head()
# Out:
# country_txt  Afghanistan  Albania  Algeria  Angola  Argentina  Armenia  \
# iyear
# 1970                   0        0        0       0          0        0
# 1971                   0        0        0       0          0        0
# 1972                   0        0        0       0          0        0
# 1973                   0        0        0       0          0        0
# 1974                   0        0        0       0          0        0
#
# country_txt  Australia  Azerbaijan  Bahrain  Bangladesh  ...  Ukraine  \
# iyear                                                    ...
# 1970                 0           0        0           0  ...        0
# 1971                 0           0        0           0  ...        0
# 1972                 0           0        0           0  ...        0
# 1973                 0           0        0           0  ...        0
# 1974                 0           0        0           0  ...        0
#
# ...

# %%
reg.plot(kind="area",figsize=(15,6),fontsize=10)
plt.title("Attacks in countries",fontsize=10)
plt.xlabel("year",fontsize=10)
plt.ylabel("Attacks",fontsize=10)
plt.show()

# %% [markdown]
# This tells us how many attacks were commited in a country in the years and displays it

# %%
ca.plot(kind="bar",figsize=(15,6),fontsize=5)
plt.title("Total Number of Attacks in each countries from 1970-2017")
plt.xlabel("country")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# This tells us about crimes committed in every country. This clesrly display that most crimes were commited in Iraq and least in Latvia.

# %%
cont=reg.transpose()
cont["Total"]=cont.sum(axis=1)
ca=cont["Total"].sort_values(ascending=False)
ca
# Out:
# country_txt
# Iraq                     1122
# India                     757
# United States             615
# Pakistan                  605
# Colombia                  552
#                          ...
# Republic of the Congo       1
# Solomon Islands             1
# Estonia                     1
# Ivory Coast                 1
# Latvia                      1
# Name: Total, Length: 123, dtype: int64

# %%
region=pd.crosstab(df.iyear,df.region_txt)
region.head()
# Out:
# region_txt  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# iyear
# 1970                            0                            0             0
# 1971                            0                            0             0
# 1972                            0                            0             0
# 1973                            0                            0             0
# 1974                            0                            0             0
#
# region_txt  East Asia  Eastern Europe  Middle East & North Africa  \
# iyear
# 1970                0               0                           0
# 1971                0               0                           0
# 1972                0               0                           0
# 1973                0               0                           0
# 1974                0               0                           0
#
# region_txt  North America  South America  South Asia  Southeast Asia  \
# iyear
# ...

# %%
region.plot(kind="area",figsize=(15,6),fontsize=10)
plt.title("Attacks in region",fontsize=10)
plt.xlabel("year",fontsize=10)
plt.ylabel("Attacks",fontsize=10)
plt.show()

# %% [markdown]
# This tells us how many attacks were commited in a region in the years and displays it

# %%
ra.plot(kind="bar",figsize=(15,6),fontsize=15)
plt.title("Total Number of Attacks in each region from 1970-2017")
plt.xlabel("region")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# The above graph display that most crimes were comiited in the South Asia region and least in Australia & Oceania region. The diffrence between both the regions is pretty large.

# %%
regt=region.transpose()
regt["Total"]=regt.sum(axis=1)
ra=regt["Total"].sort_values(ascending=False)
ra
# Out:
# region_txt
# South Asia                     2158
# Middle East & North Africa     2059
# North America                   637
# South America                   593
# Southeast Asia                  441
# Sub-Saharan Africa              392
# Western Europe                  244
# Eastern Europe                  156
# East Asia                        42
# Central Asia                     19
# Central America & Caribbean      16
# Australasia & Oceania             8
# Name: Total, dtype: int64

# %%
grouped = df.groupby('region_txt')['country_txt'].apply(set)

# %%
for region, countries in grouped.items():
    print(f"Region: {region}")
    print(", ".join(countries))
    print()
# Out:
# Region: Australasia & Oceania
# Australia, Fiji, Solomon Islands
#
# Region: Central America & Caribbean
# Belize, Guatemala, Honduras, Haiti, Costa Rica, Nicaragua, Panama, St. Lucia
#
# Region: Central Asia
# Azerbaijan, Georgia, Kazakhstan, Kyrgyzstan, Armenia
#
# Region: East Asia
# Japan, Macau, South Korea, China, Hong Kong, Taiwan
#
# Region: Eastern Europe
# Montenegro, Hungary, Estonia, Serbia-Montenegro, Latvia, Macedonia, Russia, Yugoslavia, Bulgaria, Croatia, Albania, Ukraine, Kosovo
#
# Region: Middle East & North Africa
# Syria, Algeria, Jordan, Iran, Israel, International, Lebanon, Tunisia, Egypt, Kuwait, Turkey, Saudi Arabia, Libya, West Bank and Gaza Strip, Western Sahara, Bahrain, Iraq, Yemen
#
# Region: North America
# Mexico, United States, Canada
#
# Region: South America
# Guyana, Colombia, Chile, Brazil, Peru, Venezuela, Paraguay, Argentina, Ecuador
#
# Region: South Asia
# Bangladesh, Nepal, Sri Lanka, Pakistan, Afghanistan, India
#
# Region: Southeast Asia
# ...

# %% [markdown]
#  Just for s little refrence we displayed the countries that come in diffrent regions and when we use the term region for exaple South Asia ehich countries we include.

# %% [markdown]
# Casuality = killed + wounded

# %%
df["Casualty"]=df["nkill"]+df["nwound"]
b=df[["country_txt","Casualty"]].groupby("country_txt").sum().sort_values(by="Casualty",ascending=False)
b
b.plot(kind="bar",color="#e67ffc",figsize=(15,6),fontsize=5)
# Out:
# C:\Users\Radhika Bajaj\AppData\Local\Temp\ipykernel_17088\2544223716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Casualty"]=df["nkill"]+df["nwound"]
# <Axes: xlabel='country_txt'>

# %% [markdown]
# The above graph displays the number of people killed and wounded in diffrent countries of world. Top being Iraq and last being Zambia.
#
# Below we have the bar graph representation of the same[Top 10]

# %%
t=b.head(10)
t.plot(kind="bar",color="#7ffcd9",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='country_txt'>

# %%
kill=df[["country_txt","nkill"]].groupby("country_txt").sum().sort_values(by="nkill",ascending=False)
wound=df[["country_txt","nwound"]].groupby("country_txt").sum().sort_values(by="nwound",ascending=False)

# %%
kill
# Out:
#               nkill
# country_txt
# Iraq         6732.0
# Pakistan     3628.0
# Afghanistan  2043.0
# India        1799.0
# Algeria      1260.0
# ...             ...
# Macedonia       0.0
# Malta           0.0
# Mauritania      0.0
# Niger           0.0
# Kyrgyzstan      0.0
#
# [123 rows x 1 columns]

# %%
kl=kill.head(10)
kl.plot(kind="bar",color="#fc7fcd",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='country_txt'>

# %% [markdown]
# We see above top 10 countries in which people had to loose their lives.

# %%
wound
# Out:
#               nwound
# country_txt
# Iraq         16363.0
# Pakistan      7316.0
# Afghanistan   3745.0
# India         3729.0
# Sri Lanka     2064.0
# ...              ...
# Norway           0.0
# Malta            0.0
# Niger            0.0
# Netherlands      0.0
# Zimbabwe         0.0
#
# [123 rows x 1 columns]

# %%
w=wound.head(10)
w.plot(kind="bar",color="#7fb6fc",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='country_txt'>

# %% [markdown]
# Now we see the top 10 countries in which people were wounded because of crimes.

# %%
kill.plot(kind="bar",color="#e67ffc",figsize=(15,6),fontsize=5)
# Out:
# <Axes: xlabel='country_txt'>

# %% [markdown]
# Above we have data of all countries where people were killed due to attacks.
# Top being Iraq and least being Krygystan.
#
#
# Below we have data of all countries where people were killed due to attacks.
# Top being Iraq and least being Zimbabwe.

# %%
wound.plot(kind="bar",color="#e67ffc",figsize=(15,6),fontsize=5)
# Out:
# <Axes: xlabel='country_txt'>

# %%
df["Casualty"]=df["nkill"]+df["nwound"]
k=df[["region_txt","Casualty"]].groupby("region_txt").sum().sort_values(by="Casualty",ascending=False)
k
# Out:
# C:\Users\Radhika Bajaj\AppData\Local\Temp\ipykernel_17088\2677876336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Casualty"]=df["nkill"]+df["nwound"]
#                              Casualty
# region_txt
# Middle East & North Africa    30871.0
# South Asia                    25986.0
# Sub-Saharan Africa             5989.0
# Southeast Asia                 2696.0
# Western Europe                 2159.0
# South America                  1505.0
# Eastern Europe                 1093.0
# North America                   818.0
# East Asia                       487.0
# Central Asia                     63.0
# Australasia & Oceania            49.0
# Central America & Caribbean      30.0

# %%
kil=df[["region_txt","nkill"]].groupby("region_txt").sum().sort_values(by="nkill",ascending=False)
wouund=df[["region_txt","nwound"]].groupby("region_txt").sum().sort_values(by="nwound",ascending=False)

# %%
kil
# Out:
#                               nkill
# region_txt
# Middle East & North Africa   9447.0
# South Asia                   8696.0
# Sub-Saharan Africa           2621.0
# South America                 554.0
# Southeast Asia                527.0
# Eastern Europe                415.0
# Western Europe                320.0
# North America                 203.0
# East Asia                     131.0
# Central Asia                   40.0
# Central America & Caribbean    12.0
# Australasia & Oceania          11.0

# %%
wouund
# Out:
#                               nwound
# region_txt
# Middle East & North Africa   21424.0
# South Asia                   17290.0
# Sub-Saharan Africa            3368.0
# Southeast Asia                2169.0
# Western Europe                1839.0
# South America                  951.0
# Eastern Europe                 678.0
# North America                  615.0
# East Asia                      356.0
# Australasia & Oceania           38.0
# Central Asia                    23.0
# Central America & Caribbean     18.0

# %%
kil.plot(kind="bar",color="#7ffafc",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='region_txt'>

# %% [markdown]
# Now we see the top 10 countries in which people were killed because of crimes.[above]
#
#
#
# Now we see the top 10 countries in which people were wounded because of crimes.[below]

# %%
wouund.plot(kind="bar",color="#7ffafc",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='region_txt'>

# %%
atack=df["targtype1_txt"].value_counts()
atack
# Out:
# Private Citizens & Property       2062
# Business                           897
# Police                             833
# Government (General)               775
# Military                           566
# Transportation                     327
# Religious Figures/Institutions     249
# Educational Institution            191
# Utilities                          135
# Terrorists/Non-State Militia       110
# Journalists & Media                 99
# Government (Diplomatic)             94
# Unknown                             87
# Abortion Related                    76
# Violent Political Party             71
# NGO                                 51
# Airports & Aircraft                 44
# Telecommunication                   32
# Tourists                            32
# Maritime                            18
# Food or Water Supply                10
# Other                                6
# Name: targtype1_txt, dtype: int64

# %% [markdown]
# We see the classes of people affected by crimes and below we see a bar graph for the same.
#
# We observe that most people affected were Private Citizens & Property.

# %%
atack.plot(kind="bar",color="#fce07f",figsize=(15,6),fontsize=15)
# Out:
# <Axes: >

# %%
attack=df[["targtype1_txt","Casualty"]].groupby("targtype1_txt").sum().sort_values(by="Casualty",ascending=False)
attack
# Out:
#                                 Casualty
# targtype1_txt
# Private Citizens & Property      25679.0
# Business                          8710.0
# Government (General)              7664.0
# Police                            7617.0
# Religious Figures/Institutions    6111.0
# Transportation                    5225.0
# Military                          5150.0
# Educational Institution           1239.0
# Government (Diplomatic)           1218.0
# Terrorists/Non-State Militia       955.0
# Airports & Aircraft                520.0
# Violent Political Party            493.0
# Unknown                            239.0
# Journalists & Media                211.0
# NGO                                185.0
# Other                              181.0
# Tourists                           174.0
# Utilities                           71.0
# Telecommunication                   45.0
# Maritime                            41.0
# Food or Water Supply                13.0
# ...

# %%
attack.plot(kind="bar",color="#7fd2fc",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='targtype1_txt'>

# %% [markdown]
# Classes of people that were killed and wounded.
#
#
# Most being Private Citizens & Property and least Abortion Related

# %%
ktt=df[["targtype1_txt","nkill"]].groupby("targtype1_txt").sum().sort_values(by="nkill",ascending=False)
ktt.plot(kind="bar",color="#7fd2fc",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='targtype1_txt'>

# %% [markdown]
# Classes of people that were killed.
#
#
# Most being Private Citizens & Property and least Abortion Related

# %%
wtt=df[["targtype1_txt","nwound"]].groupby("targtype1_txt").sum().sort_values(by="nwound",ascending=False)
wtt.plot(kind="bar",color="#7fd2fc",figsize=(15,6),fontsize=15)
# Out:
# <Axes: xlabel='targtype1_txt'>

# %% [markdown]
# Classes of people that were wounded.
#
#
#
# Most being Private Citizens & Property and least Abortion Related

# %% [markdown]
# # General Figures

# %%
cy=df.loc[:,"Casualty"].sum()
print("Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :\n",cy)
# Out:
# Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :
#  71746.0

# %%
kill=df.loc[:,"nkill"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",kill)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  22977.0

# %%
wound=df.loc[:,"nwound"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",wound)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  48769.0

# %% [markdown]
# # OBSERVATIONS:

# %% [markdown]
# YEAR:
#
# (1) Attacks
#
#
#     (a) Most number of attacks: 16903 in 2014
#     (b) Least number of attacks: 471 in 1971
#
#
# (2) Casualties
#
#
#     (a) Most number of casualties: 85618 in 2014
#     (b) Least number of casualties: 255 in 1971
#
#
# (3) Killed
#
#
#     (a) Most number of people killed: 44490 in 2014
#     (b) Least number of people killed: 173 in 1971
#
#
#
# COUNTRY:
#
#
# (4) Cauality
#
#
#     (a) Most number of casualties: 213279 in "Iraq"
#     (b) Least number of casualties: 22926 in "Philippines"
#
#
# (5) Killed
#
#
#     (a) Most number of people killed: 78589 in "Iraq"
#     (b) Least number of people killed: 12053 in "El Salvador"
#
#
# (6) Wounded
#
#
#     (a) Most number of people wounded: 134690 in "Iraq"
#     (b) Least number of people wounded: 10328 in "Colombia"
#
#
# REGION:
#
#
# (7) Casualties
#
#
#     (a) Most number of casualties: 351950 in "Middle East & North Africa"
#     (b) Least number of casualties: 410 in Australasia & Oceania
#
#
# (8) Killed
#
#
#     (a) Most number of people killed: 137642 in "Middle East & North Africa"
#     (b) Least number of people killed: 150 in "Australasia & Oceania"
#
#
# (9) Wounded
#
#
#     (a) Most number of people wounded: 214308 in "Middle East & North Africa"
#     (b) Least number of people wounded: 260 in "Australasia & Oceania"
#
#
# TARGET TYPE:
#
#
# (10) Casualties
#
#
#     (a) Most number of casualties : 319176 over "Private Citizens & Property"
#     (b) Least number of casualties : 56 over "Abortion Related"
#
#
# (11) Killed
#
#
#     (a) Most number of people killed : 140504 over "Private Citizens & Property"
#     (b) Least number of people killed : 10 over "Abortion Related"
#
#
# (12) Wounded
#
#
#     (a) Most number of people wounded : 178672 over "Private Citizens & Property"
#     (b) Least number of people wounded : 46 over "Abortion Related"
